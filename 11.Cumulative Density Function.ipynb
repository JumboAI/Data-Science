# %%
import pandas as pd
dataset=pd.read_csv("PrePlacement.csv")

# %%
dataset.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
#Gona merge quan and qual

# %%
import seaborn as sns
#!pip install seaborn

# %%
sns.distplot(dataset["ssc_p"])
#the edge is histogram and probability density #bell curve
# Out:
# C:\Users\Rajesh\Anaconda3\envs\aiml\lib\site-packages\ipykernel_launcher.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   """Entry point for launching an IPython kernel.

# %%
def get_pdf_probability(dataset,startrange,endrange):
    from matplotlib import pyplot
    from scipy.stats import norm
    import seaborn as sns
    ax=sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color ='black')
    pyplot.axvline(startrange,color='Red')
    pyplot.axvline(endrange,color='Red')
    #generate a sample
    sample=dataset
    #calculate parameters
    sample_mean=sample.mean()
    sample_std=sample.std()
    print('Mean=%.3f, Standard Deviation=%3.f'%(sample_mean,sample_std))
    #define the distribution
    dist=norm(sample_mean,sample_std)
    #sample probabilities for a range of outcomes
    values=[value for value in range(startrange,endrange)]
    probabilities=[dist.pdf(value) for value in values]
    prob=sum(probabilities)
    print("The area between range({},{}):{}".format(startrange,endrange,sum(probabilities)))
    return prob

# %%
#to get the probability of Density Function
#34% prob
get_pdf_probability(dataset["ssc_p"],60,70)
# Out:
# Mean=67.303, Standard Deviation= 11
# The area between range(60,70):0.3449514151280293
# C:\Users\Rajesh\Anaconda3\envs\aiml\lib\site-packages\ipykernel_launcher.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   """
# 0.3449514151280293

# %% [markdown]
# #explain the line by line  funtions is the assignment
# #from matplotlib import pyplot
#  from scipy.stats import norm
#  import seaborn as sns
#
# #these lines import the libraries for flotting matplot to plot, norm from Scipy used
# #to generate normal distribution and seaborn used for statistical data visualization

# %% [markdown]
# ax=sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color ='Green')
# pyplot.axvline(startrange,color='Red')
# pyplot.axvline(endrange,color='Red')
#
# #This line creates a kernel density estimate (KDE) plot using Seaborn.
# #The dataset is the data you want to visualize
# #These lines add vertical lines to the plot using axvline.
# #The first line adds a red vertical line at the position specified by startrange,
# #and the second line adds a red vertical line at the position specified by endrange.
# #These lines help visually indicate the range of interest on the plot

# %% [markdown]
#     # sample=dataset
#     #sample_mean=sample.mean()
#     #sample_std=sample.std()
#     #print('Mean=%.3f, Standard Deviation=%3.f'%(sample_mean,sample_std))
# #create a variable 'sample'and assign the dataset values,
# #these line calculate the mean and std of the sample and the result are stored in varialbe sample_mean and sample_std
# #line prints the mean and std of the sample. The 3% formatting is used floating point number with 3 decimal place

# %% [markdown]
# #values=[value for value in range(startrange,endrange)]
# #probabilities=[dist.pdf(value) for value in values]
# #prob=sum(probabilities)
# print("The area between range({},{}):{}".format(startrange,endrange,sum(probabilities)))
# #This line creates a list called values containing a range of values from startrange to endrange
# #This line calculates the probability density function (PDF) for each value in the values list using the
# #pdf method of the distribution object (dist). The result is a list called probabilities containing the
# #PDF values for each corresponding value in the values list
# #This line calculates the sum of all the probabilities in the probabilities list.
# #The variable prob now holds the total probability for the specified range.&&&one liner for loop

# %% [markdown]
# Cumulative start here

# %%
from statsmodels.distributions.empirical_distribution import ECDF
ecdf=ECDF(dataset["ssc_p"])
ecdf(78)
# Out:
# 0.827906976744186
